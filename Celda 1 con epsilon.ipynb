# %%
using Plots

# %%
#La función es indefinida de V= 9.9999999999999999 a V= 10.000000000000001, entonces el epsilon adecuado es:

epsilon= 0.000000000000001

function alpha_n(V)
    α_n = (0.01 * (10 - V)) / (ℯ^((10-V) / 10) .- 1)

if abs(V-10) < epsilon
        return 0.1
    else 
        return α_n
    end 
end

alpha_n(9.999999999999999)
plot(alpha_n, 9.5:0.1:10.5)


#Observamos que la gráfica ya no tiene un intervalo abierto de V= 9.9999999999999999 a V= 10.000000000000001

# %%
alpha_n(10.000000000000001)
# Out:
# 0.08

# %%
#Comprobación, por L´Hopital obtenemos: 

alpha_n(9.9999999999999999)
# Out:
# 0.1

# %%
alpha_n(10)
# Out:
# 0.1
